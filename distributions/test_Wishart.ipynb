# %%
from wishart import Wishart
import numpy as np

# %%
import scipy

# %%
x = scipy.special.multigammaln(1.5, 3)
print x
# Out:
# 2.16867753406

# %%
W_0 = np.identity(3) + np.ones((3,3))*0.2
W = Wishart(W_0, 4)

# %%
p = 0
for i in xrange(100):
    x = W.sample()
    #print x
    p += W.pdf(x)
    print p
    #inv = W.sample_inv()
# Out:
# 0.00193437528509
# 0.0187948564307
# 0.0191326512573
# 0.019565719004
# 0.0198022212851
# 0.0198027046483
# 0.0390176736007
# 0.0547678630496
# 0.0605178518988
# 0.0630204808284
# 0.084824501981
# 0.091738642944
# 0.109644910164
# 0.121207764227
# 0.138025475707
# 0.138098367082
# 0.155845987239
# 0.155846009667
# 0.16574267243
# 0.176605319952
# 0.177428674696
# 0.196646521234
# 0.210483764193
# 0.220199436893
# 0.238859832244
# 0.251182971994
# 0.266497750279
# 0.269486942288
# 0.26952126321
# 0.288299676166
# 0.306927546886
# 0.313749348781
# 0.330507167899
# 0.344861375366
# 0.36333718203
# 0.382759007208
# 0.383051524034
# 0.384632616115
# 0.405901915817
# 0.411276820287
# 0.411277101329
# 0.415620722543
# 0.432100154995
# 0.453153970541
# 0.458838462493
# 0.473082308818
# 0.474372177494
# 0.493847807178
# 0.505231393456
# 0.505235155004
# 0.519163682685
# 0.519631757341
# 0.535223963646
# 0.554954335283
# 0.566037144284
# 0.582285781981
# 0.605575346377
# 0.617558319435
# ...

# %%
print p
# Out:
# 1.07507547031
